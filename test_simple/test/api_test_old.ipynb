# %% [markdown]
# # Try an API call

# %%
import json
import google.auth.credentials
import google.auth.transport.requests
import requests

# %%
project_id = "circlestar-2024"

# %%
# Use different base for connecting to cloud run vs. local testing

base_url = "https://test-simple-98481520348.us-east5.run.app" # cloud
#base_url = 'http://127.0.0.1:5000/' # local
base_url
# Out:
# 'https://test-simple-98481520348.us-east5.run.app'

# %%
audience = '/'.join([base_url, "hello_world"])

# %%
headers = {"Content-Type": "application/json"}

response = requests.get(audience, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# hello world

# %%
audience_named = '/'.join([base_url, "hello", "Val"])

# %%
headers = {"Content-Type": "application/json"}

response = requests.get(audience_named, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# {
#   "message": "Hello, Val"
# }

# %%
audience_named = '/'.join([base_url, "hello/"])
headers = {"Content-Type": "application/json"}

response = requests.get(audience_named, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 404
# <!doctype html>
# <html lang=en>
# <title>404 Not Found</title>
# <h1>Not Found</h1>
# <p>The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.</p>

# %%
audience_topic = '/'.join([base_url, "positivity/"])
headers = {"Content-Type": "application/json"}

response = requests.get(audience_topic, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# {
#   "message": "It brings the majestic power of Microsoft's 1990s desktop dominance into the modern era, but with infinitely more SQL.",
#   "topic": "Azure"
# }

# %%
requests.get(audience_topic)
# Out:
# <Response [200]>
